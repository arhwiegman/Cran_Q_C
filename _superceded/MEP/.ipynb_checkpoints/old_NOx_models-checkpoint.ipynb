# %% [markdown]
# # statistics on NO3 concentration
#
# need to convert NOx values to polygons of MEP name.
#
# 1. exploratory regression
# 2. kriging
# 3. geographically wieghted regression
# 4. random forest
# 5. random forest with krig

# %%
arcpy.management.CopyFeatures(
    in_features="Yearly_Nitrate_Concentration_Averages_in_Public_Supply_Wells",
    out_feature_class=r"C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy",
    config_keyword="",
    spatial_grid_1=None,
    spatial_grid_2=None,
    spatial_grid_3=None
)

arcpy.management.AlterField(
    in_table=r"C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy",
    field="Lat",
    new_field_name="Lat",
    new_field_alias="Lat",
    field_type="DOUBLE",
    field_length=8,
    field_is_nullable="NULLABLE",
    clear_field_alias="DO_NOT_CLEAR"
)
arcpy.management.AlterField(
    in_table=r"C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy",
    field="Long",
    new_field_name="Long",
    new_field_alias="Long",
    field_type="DOUBLE",
    field_length=8,
    field_is_nullable="NULLABLE",
    clear_field_alias="DO_NOT_CLEAR"
)
arcpy.management.AlterField(
    in_table=r"C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy",
    field="NO3",
    new_field_name="NO3",
    new_field_alias="NO3",
    field_type="DOUBLE",
    field_length=8,
    field_is_nullable="NULLABLE",
    clear_field_alias="DO_NOT_CLEAR"
)

arcpy.management.Merge(
    inputs=r"C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge;C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy",
    output=r"C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge_Well",
    field_mappings=r'Lat "Lat" true true false 8 Double 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Lat,-1,-1,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,Lat,-1,-1;Long "Long" true true false 8 Double 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Long,-1,-1,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,Long,-1,-1;Region "Region" true true false 254 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Region,0,254;MEP "MEP" true true false 254 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,MEP,0,254;System "System" true true false 254 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,System,0,254;Region_MEP "Region_MEP" true true false 254 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Region_MEP,0,254;SUBW_NAME "SUBW_NAME" true true false 254 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,SUBW_NAME,0,254;NO3 "NO3" true true false 8 Double 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,NO3,-1,-1,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,NO3,-1,-1;Code "Code" true true false 255 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Code,0,255;Start_Date "Start_Date" true true false 8 Date 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,Start_Date,-1,-1;End_Date "End_Date" true true false 8 Date 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,End_Date,-1,-1;n "n" true true false 8 Double 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\MEP_NO3_Merge,n,-1,-1;OBJECTID "OBJECTID" true true false 2 Short 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,OBJECTID,-1,-1;SOURCE_ID "SOURCE_ID" true true false 11 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,SOURCE_ID,0,11;SITE_NAME "SITE_NAME" true true false 39 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,SITE_NAME,0,39;TOWN "TOWN" true true false 12 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,TOWN,0,12;TYPE "TYPE" true true false 4 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,TYPE,0,4;ZII_NUM "ZII_NUM" true true false 2 Short 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,ZII_NUM,-1,-1;PWS_ID "PWS_ID" true true false 7 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,PWS_ID,0,7;PWS_NAME "PWS_NAME" true true false 40 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,PWS_NAME,0,40;LOC_CODE "LOC_CODE" true true false 4 Long 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,LOC_CODE,-1,-1;YEAR "YEAR" true true false 2 Short 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,YEAR,-1,-1;SITE_NAME_ "SITE_NAME_" true true false 34 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,SITE_NAME_,0,34;EmbaymentI "EmbaymentI" true true false 1 Text 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,EmbaymentI,0,1;LayerID "LayerID" true true false 2 Short 0 0,First,#,C:\Workspace\Geodata\MEP\Default.gdb\Nitrate_Concentration_Averages_in_Public_Supply_Wells_Copy,LayerID,-1,-1',
    add_source="ADD_SOURCE_INFO"
)

# %%
#1. exploratory regression
arcpy.stats.ExploratoryRegression(
    Input_Features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1",
    Dependent_Variable="NOx",
    Candidate_Explanatory_Variables="SLOPE_0;SLOPE_A;SLOPE_B;SLOPE_C;SLOPE_D;FRMLNDCLS_Farmland_of_unique_importance;FRMLNDCLS_Not_prime_farmland;HYDROLGRP_A;HYDROLGRP_D;HYDRCRATNG_No;DRAINCLASS_Subaqueous;DRAINCLASS_Very_poorly_drained;DEP2WATTBL_0;CLAY_0;CLAY_30;OM_0;OM_25;NLEACHING_Low;NLEACHING_Moderate;NLEACHING_Not_rated;COVERNAME_Developed_Open_Space;COVERNAME_Impervious;COVERNAME_Water;USEGENNAME_Commercial;USEGENNAME_Residential___single_family;USEGENNAME_Right_of_way;USEGENNAME_Tax_exempt;CRANBERRY_1;ACTIVE_1;HSG_D;HYDRIC;NaturalCover;Use_Res;Use_ResComMix;Use_Mix",
    Weights_Matrix_File=None,
    Output_Report_File=None,
    Output_Results_Table=None,
    Maximum_Number_of_Explanatory_Variables=5,
    Minimum_Number_of_Explanatory_Variables=1,
    Minimum_Acceptable_Adj_R_Squared=0.5,
    Maximum_Coefficient_p_value_Cutoff=0.05,
    Maximum_VIF_Value_Cutoff=7.5,
    Minimum_Acceptable_Jarque_Bera_p_value=0.1,
    Minimum_Acceptable_Spatial_Autocorrelation_p_value=0.1
)

# %%
# 2. Kriging
with arcpy.EnvManager(extent='310841.39357006 4562982.5587141 433979.062129724 4664336.65937132 PROJCS["NAD_1983_UTM_Zone_19N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-69.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', mask="MEP_SUBW_NAME"):
    arcpy.ga.EmpiricalBayesianKriging(
        in_features="MEP_Monitoring_Sites_MeasOnly_SummaryData",
        z_field="MEP_SummaryData_Coords_XYTableToPoint_NOx",
        out_ga_layer="bayes_krig_NOx",
        out_raster=None,
        cell_size=0.00431192471234902,
        transformation_type="LOGEMPIRICAL",
        max_local_points=100,
        overlap_factor=1,
        number_semivariograms=100,
        search_neighborhood="NBRTYPE=StandardCircular RADIUS=0.339830256402827 ANGLE=0 NBR_MAX=15 NBR_MIN=10 SECTOR_TYPE=ONE_SECTOR",
        output_type="PREDICTION",
        quantile_value=0.5,
        threshold_type="EXCEED",
        probability_threshold=None,
        semivariogram_model_type="EXPONENTIAL"
    )

# %%
'''Start Time: Tuesday, July 25, 2023 12:49:28 PM
Calculating Simple Kriging – Default
Calculating Simple Kriging – Optimized
Calculating Simple Kriging – Trend
Calculating Simple Kriging – Trend and transformation
Calculating Ordinary Kriging – Default
Calculating Ordinary Kriging – Optimized
Calculating Universal Kriging – Default
Calculating Universal Kriging – Optimized
Calculating Empirical Bayesian Kriging - Default

Warning(s) for dataset: Length of the radius of the search circle = 3493.7 meters.
Calculating Empirical Bayesian Kriging - Advanced

Warning(s) for dataset: Length of the radius of the search circle = 3493.7 meters.
Calculating Kernel Interpolation

Warning(s) for dataset: Length of the radius of the search circle = 3493.7 meters.
------------------------------------------------
RANK | NAME
------------------------------------------------
1    | Empirical Bayesian Kriging - Advanced
2    | Ordinary Kriging – Optimized
3    | Simple Kriging – Trend
4    | Universal Kriging – Optimized
5    | Ordinary Kriging – Default
6    | Empirical Bayesian Kriging - Default
7    | Universal Kriging – Default
8    | Simple Kriging – Optimized
9    | Simple Kriging – Default
10   | Simple Kriging – Trend and transformation
11   | Kernel Interpolation
------------------------------------------------
Succeeded at Tuesday, July 25, 2023 12:49:43 PM (Elapsed Time: 15.03 seconds)
'''
arcpy.ga.ExploratoryInterpolation(
    in_features="NO3_Merge_MEP_CCRO_CCWells",
    value_field="NO3",
    out_cv_table=r"C:\Workspace\Geodata\MEP\Default.gdb\ExploratoryInterpolation1",
    out_geostat_layer="_exploratory_krig_out",
    interp_methods="SIMPLE_KRIGING;ORDINARY_KRIGING;UNIVERSAL_KRIGING;EBK;KERNEL_INTERPOLATION",
    comparison_method="SINGLE",
    criterion="ACCURACY",
    criteria_hierarchy="ACCURACY PERCENT #",
    weighted_criteria="ACCURACY 1",
    exclusion_criteria=None
)

# %%
"""
Start Time: Tuesday, July 25, 2023 12:58:53 PM
WARNING 001605: Distances for Geographic Coordinates (degrees, minutes, seconds) are analyzed using Chordal Distances in meters.
WARNING 000853: The default neighborhood search threshold was 6371.5854 Meters.
Global Moran's I Summary
Moran's Index	0.114834
Expected Index	-0.003484
Variance	0.000637
z-score	4.686610
p-value	0.000003
Distance measured in Meters
Succeeded at Tuesday, July 25, 2023 12:58:56 PM (Elapsed Time: 3.42 seconds)
"""

arcpy.stats.SpatialAutocorrelation(
    Input_Feature_Class="NO3_Merge_MEP_CCRO_CCWells",
    Input_Field="NO3",
    Generate_Report=None,
    Conceptualization_of_Spatial_Relationships="FIXED_DISTANCE_BAND",
    Distance_Method="EUCLIDEAN_DISTANCE",
    Standardization="ROW",
    Distance_Band_or_Threshold_Distance=None,
    Weights_Matrix_File=None,
    number_of_neighbors=None
)

# %%
'''
Start Time: Tuesday, July 25, 2023 1:08:18 PM
Warning(s) for dataset: Length of the radius of the search circle = 37830 meters.
Succeeded at Tuesday, July 25, 2023 2:33:21 PM (Elapsed Time: 1 hours 25 minutes 2 seconds)
'''
with arcpy.EnvManager(outputCoordinateSystem='PROJCS["NAD_1983_UTM_Zone_19N",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",500000.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-69.0],PARAMETER["Scale_Factor",0.9996],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]', snapRaster="lidar_le5pct", extent='208298.114652191 767318.392642676 357483.260449944 894224.238614197 PROJCS["NAD_1983_StatePlane_Massachusetts_Mainland_FIPS_2001",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Lambert_Conformal_Conic"],PARAMETER["False_Easting",200000.0],PARAMETER["False_Northing",750000.0],PARAMETER["Central_Meridian",-71.5],PARAMETER["Standard_Parallel_1",41.71666666666667],PARAMETER["Standard_Parallel_2",42.68333333333333],PARAMETER["Latitude_Of_Origin",41.0],UNIT["Meter",1.0]]', cellSize="lidar_le5pct", mask="IL_DWMWPP_WATERSHEDS_POLY_SE"):
    arcpy.ga.EmpiricalBayesianKriging(
        in_features=r"C:\Workspace\Geodata\MEP\Default.gdb\NO3_Merge_MEP_CCRO_CCWells",
        z_field="NO3",
        out_ga_layer="bayes_krig_NO3_Merge_MEP_CCRO_CCWells",
        out_raster=r"C:\Workspace\Geodata\MEP\Default.gdb\bayes_krig_NO3_Merge_MEP_CCRO_CCWells",
        cell_size=10,
        transformation_type="LOGEMPIRICAL",
        max_local_points=100,
        overlap_factor=1,
        number_semivariograms=100,
        search_neighborhood="NBRTYPE=StandardCircular RADIUS=0.339830256402827 ANGLE=0 NBR_MAX=15 NBR_MIN=10 SECTOR_TYPE=ONE_SECTOR",
        output_type="PREDICTION",
        quantile_value=0.5,
        threshold_type="EXCEED",
        probability_threshold=None,
        semivariogram_model_type="EXPONENTIAL"
    )

# %%
# 3. Geographically weighted regression
arcpy.stats.GWR(
    in_features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1",
    dependent_variable="NOx",
    model_type="CONTINUOUS",
    explanatory_variables="SLOPE_C;SLOPE_D;COVERNAME_Developed_Open_Space;COVERNAME_Impervious;USEGENNAME_Residential___single_family;USEGENNAME_Right_of_way;NaturalCover",
    output_features=r"C:\Workspace\Geodata\MEP\Default.gdb\df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1_GWR",
    neighborhood_type="DISTANCE_BAND",
    neighborhood_selection_method="GOLDEN_SEARCH",
    minimum_number_of_neighbors=None,
    maximum_number_of_neighbors=None,
    minimum_search_distance=None,
    maximum_search_distance=None,
    number_of_neighbors_increment=None,
    search_distance_increment=None,
    number_of_increments=None,
    number_of_neighbors=None,
    distance_band=None,
    prediction_locations=None,
    explanatory_variables_to_match=None,
    output_predicted_features=None,
    robust_prediction="ROBUST",
    local_weighting_scheme="BISQUARE",
    coefficient_raster_workspace=None,
    scale=None
)

# %%
# 4. Random Forest
arcpy.stats.Forest(
    prediction_type="TRAIN",
    in_features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1",
    variable_predict="NOx",
    treat_variable_as_categorical="NUMERIC",
    explanatory_variables="SLOPE_0 false;SLOPE_A false;SLOPE_C false;SLOPE_D false;FRMLNDCLS_Not_prime_farmland false;HYDRCRATNG_No false;HYDRCRATNG_Yes false;DEP2WATTBL_0 false;NLEACHING_Low false;NLEACHING_Moderate false;COVERNAME_Developed_Open_Space false;COVERNAME_Impervious false;COVERNAME_Water false;USEGENNAME_Residential___single_family false;USEGENNAME_Right_of_way false;USEGENNAME_Tax_exempt false;CRANBERRY_1 false;ACTIVE_1 false;HSG_D false;HYDRIC false;NaturalCover false;Use_Res false;Use_ResComMix false;Use_Mix false",
    distance_features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint",
    explanatory_rasters=None,
    features_to_predict=None,
    output_features=None,
    output_raster=None,
    explanatory_variable_matching=None,
    explanatory_distance_matching=None,
    explanatory_rasters_matching=None,
    output_trained_features=None,
    output_importance_table=None,
    use_raster_values="TRUE",
    number_of_trees=500,
    minimum_leaf_size=None,
    maximum_depth=None,
    sample_size=100,
    random_variables=5,
    percentage_for_training=15,
    output_classification_table=None,
    output_validation_table=r"C:\Workspace\Geodata\MEP\Default.gdb\randforest_validation_230706",
    compensate_sparse_categories="FALSE",
    number_validation_runs=10,
    calculate_uncertainty="TRUE",
    output_trained_model=r"C:\Workspace\Geodata\MEP\randforest_fit_230706.ssm"
)

# to make predictions with this model use:
# https://pro.arcgis.com/en/pro-app/latest/tool-reference/spatial-statistics/predict-using-spatial-statistics-model-file.htm

# %%
# 4. Random forest with Kriging as predictor.
arcpy.stats.Forest(
    prediction_type="TRAIN",
    in_features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1",
    variable_predict="NOx",
    treat_variable_as_categorical="NUMERIC",
    explanatory_variables="SLOPE_0 false;SLOPE_A false;SLOPE_C false;SLOPE_D false;FRMLNDCLS_Not_prime_farmland false;HYDRCRATNG_No false;HYDRCRATNG_Yes false;DEP2WATTBL_0 false;NLEACHING_Low false;NLEACHING_Moderate false;COVERNAME_Developed_Open_Space false;COVERNAME_Impervious false;COVERNAME_Water false;USEGENNAME_Residential___single_family false;USEGENNAME_Right_of_way false;USEGENNAME_Tax_exempt false;CRANBERRY_1 false;ACTIVE_1 false;HSG_D false;HYDRIC false;NaturalCover false;Use_Res false;Use_ResComMix false;Use_Mix false",
    distance_features=None,
    explanatory_rasters="NLCD_2004_Impervious_L48_20210604_Elvh5FmIMCBDmrosSCKG.tiff #;Krig_NOx #",
    features_to_predict=None,
    output_features=None,
    output_raster=None,
    explanatory_variable_matching=None,
    explanatory_distance_matching=None,
    explanatory_rasters_matching=None,
    output_trained_features=None,
    output_importance_table=None,
    use_raster_values="TRUE",
    number_of_trees=500,
    minimum_leaf_size=None,
    maximum_depth=None,
    sample_size=100,
    random_variables=5,
    percentage_for_training=10,
    output_classification_table=None,
    output_validation_table=r"C:\Workspace\Geodata\MEP\Default.gdb\randforest_validation_230706",
    compensate_sparse_categories="FALSE",
    number_validation_runs=20,
    calculate_uncertainty="TRUE",
    output_trained_model=r"C:\Workspace\Geodata\MEP\outputs\randforest_fit_230706.ssm"
)

# %%
# this works quite well R2 on cross validation of 0.73

arcpy.stats.Forest(
    prediction_type="TRAIN",
    in_features="df_MEP_Monitoring_Avg_Geo_Merge_XYTableToPoint1",
    variable_predict="NOx",
    treat_variable_as_categorical="NUMERIC",
    explanatory_variables="SLOPE_0 false;SLOPE_A false;SLOPE_C false;SLOPE_D false;FRMLNDCLS_Not_prime_farmland false;"+
    "HYDRCRATNG_No false;HYDRCRATNG_Yes false;DEP2WATTBL_0 false;NLEACHING_Low false;NLEACHING_Moderate false;"+
    "COVERNAME_Developed_Open_Space false;COVERNAME_Impervious false;COVERNAME_Water false;"+
    "USEGENNAME_Residential___single_family false;USEGENNAME_Right_of_way false;USEGENNAME_Tax_exempt false;CRANBERRY_1 false;"+
    "ACTIVE_1 false;HSG_D false;HYDRIC false;NaturalCover false;Use_Res false;Use_ResComMix false;Use_Mix false",
    distance_features=None,
    explanatory_rasters="Krig_NOx #;bayes_krig_NOx #;Extract_LiDA1 #;NLCD_2004_Impervious_L48_20210604_Elvh5FmIMCBDmrosSCKG.tiff #",
    features_to_predict=None,
    output_features=None,
    output_raster=None,
    explanatory_variable_matching=None,
    explanatory_distance_matching=None,
    explanatory_rasters_matching=None,
    output_trained_features=r"C:\Workspace\Geodata\MEP\outputs\randforest_trained_230706.shp",
    output_importance_table=r"C:\Workspace\Geodata\MEP\outputs\randforest_importance_20230706.dbf",
    use_raster_values="TRUE",
    number_of_trees=500,
    minimum_leaf_size=None,
    maximum_depth=None,
    sample_size=100,
    random_variables=5,
    percentage_for_training=10,
    output_classification_table=None,
    output_validation_table=r"C:\Workspace\Geodata\MEP\Default.gdb\randforest_validation_230706",
    compensate_sparse_categories="FALSE",
    number_validation_runs=20,
    calculate_uncertainty="TRUE",
    output_trained_model=r"C:\Workspace\Geodata\MEP\outputs\randforest_fit_230706.ssm"
)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\ast.py, in parse:
# Line 50:    return compile(source, filename, mode, flags,
#
# SyntaxError: invalid syntax (<string>, line 39)
# ---------------------------------------------------------------------------

# %%
arcpy.conversion.PolygonToRaster(
    in_features="subs_tt_le5_lclu16",
    value_field="USEGENCODE",
    out_rasterdataset=r"C:\Workspace\Geodata\MEP\Default.gdb\lclu16_usegencode",
    cell_assignment="CELL_CENTER",
    priority_field="NONE",
    cellsize=5,
    build_rat="BUILD"
)

arcpy.conversion.PolygonToRaster(
    in_features="subs_tt_le5_lclu16",
    value_field="COVERCODE",
    out_rasterdataset=r"C:\Workspace\Geodata\MEP\Default.gdb\lclu16_covercode",
    cell_assignment="CELL_CENTER",
    priority_field="NONE",
    cellsize=5,
    build_rat="BUILD"
)

# %%
arcpy.conversion.PolygonToRaster(
    in_features="Soils Polygons with Top 20 Fields",
    value_field="SLOPE_1",
    out_rasterdataset=r"C:\Workspace\Geodata\MEP\Default.gdb\soil_slope",
    cell_assignment="CELL_CENTER",
    priority_field="NONE",
    cellsize=5,
    build_rat="BUILD"
)

# %%
arcpy.management.CopyFeatures(
    in_features=r"DWMWPP_WaterQuality\DWMWPP_WATER_QUALITY_STATIONS",
    out_feature_class=r"C:\Workspace\Geodata\MEP\outputs\DNWPP_WQ_Only.shp",
    config_keyword="",
    spatial_grid_1=None,
    spatial_grid_2=None,
    spatial_grid_3=None
)
