# %% [markdown]
# # Preprocess Monitoring Points
#
# Adrian Wiegman | arhwiegman.github.io | adrian.wiegman@usda.gov
#
# 2023-03-30
#
# ---
#
# In this notebook extract subwatershed ids for each monitoring within the [MEP study area](https://www.mass.gov/guides/the-massachusetts-estuaries-project-and-reports).
#
# input data is an excel table of points coordinates and watershed ids.
#
# the output will be a list of subwatershed ids with asociated point ids.
#
# Processing Steps
#
#
# the fields in the Assess data will be used generate landcover classes for N loading
# then the TaxPar LOC_ID's will be used to index the landcover classes for each discrete
# the merged TaxPar layer will be intersected with watershed boundaries

# %%
# this codeblock sets up the environment from jupyter notebooks
setup_notebook = "C:/Users/Adrian.Wiegman/Documents/GitHub/Wiegman_USDA_ARS/MEP/_Setup.ipynb"
# %run $setup_notebook # magic command to run the notebook 
fn_hello()
# Out:
# ***
# loading python modules...
#
#   `module_list` contains names of all loaded modules
#
# ...module loading complete
#
# ***
# setting up arcpy environment...
#
#  input file directory (`idr`): C:\Workspace\Geodata\Massachusetts\
#  working directory (`wdr`): C:\Workspace\Geodata\MEP\
#  temp dir (`tdr`): C:\Workspace\Geodata\MEP\temp
#  output dir (`odr`): C:\Workspace\Geodata\MEP\outputs
#  default geodatabase path: C:\Workspace\Geodata\MEP\Default.gdb
#  output coordinate system: NAD_1983_UTM_Zone_19N
#
# ... env setup complete
#
# ***
# loading functions...
#
# type `fn_`+TAB to autocomplete
#
#  the object `def_list` contains user defined function names:
#    fn_get_info
#    fn_hello
#    fn_recursive_glob_search
#    fn_regex_search_replace
#    fn_regex_search_0
#    fn_arcpy_table_to_excel
#    fn_arcgis_table_to_df
#    fn_arcgis_table_to_np_to_pd_df
#
#  use ??{insert fn name} to inspect
#  for example running `??fn_get_info` returns:
# Signature: fn_get_info(name='fn_get_info')
# Docstring: <no docstring>
# Source:
# def fn_get_info(name='fn_get_info'):
#     get_ipython().run_line_magic('pinfo2', '$name')
# File:      c:\workspace\geodata\mep\<ipython-input-1-ba824f911473>
# Type:      function
#
#  you can also use `fn_get_info(name={insert fn name})` to do the same thing as `??{insert fn name}`
#
# ...function loading complete
#
#
# +++SETUP COMPLETE+++
#
#
# hello world

# %% [raw]
# # Add the points datalayer to the default geodatabase
# with arcpy.EnvManager(scratchWorkspace=r"C:\Workspace\Geodata\MEP\Default.gdb", workspace=r"C:\Workspace\Geodata\MEP\Default.gdb"):
#     arcpy.conversion.FeatureClassToGeodatabase(r"C:\Workspace\Geodata\Nload\outputs\MEP\MEP_Monitoring_Sites_MeasOnly.shp", r"C:\Workspace\Geodata\MEP\Default.gdb")

# %% [raw]
# # last run 4/8/2023
# # read in data
# fn_arcpy_table_to_excel('MEP_Monitoring_Sites_MeasOnly',odr,'MEP_Monitoring_Sites_MeasOnly_TableToExcel.xlsx')

# %%
inpath = os.path.join(odr,'MEP_Monitoring_Sites_MeasOnly_TableToExcel.xlsx')
df_in = pd.read_excel(inpath)
#df_in = fn_arcgis_table_to_df('MEP_Monitoring_Sites_MeasOnly').reset_index()
df_in.rename(columns={"OBJECTID":"FID"},inplace=True)
df_in.info()
df_in.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         98 non-null     int64
#  1   Lat         98 non-null     float64
#  2   Lon         98 non-null     float64
#  3   Region      98 non-null     object
#  4   MEP         98 non-null     object
#  5   Site_Name   98 non-null     object
#  6   Region_MEP  98 non-null     object
#  7   SUBW_NAME   68 non-null     object
#  8   Notes_AW    11 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 7.0+ KB
#    FID        Lat        Lon        Region       MEP         Site_Name  \
# 0    1  41.681859 -70.918844  Buzzards Bay  Acushnet    Acushnet River
# 1    2  41.681859 -70.918844  Buzzards Bay  Acushnet    Acushnet River
# 2    3  41.681859 -70.918844  Buzzards Bay  Acushnet    Acushnet River
# 3    4  41.681859 -70.918844  Buzzards Bay  Acushnet    Acushnet River
# 4    5  41.553741 -71.126612  Buzzards Bay  Westport  Adamsville Brook
#
#                                    Region_MEP SUBW_NAME Notes_AW
# 0    Buzzards Bay > Acushnet > Acushnet River       NaN      NaN
# 1    Buzzards Bay > Acushnet > Acushnet River       NaN      NaN
# 2    Buzzards Bay > Acushnet > Acushnet River       NaN      NaN
# 3    Buzzards Bay > Acushnet > Acushnet River       NaN      NaN
# 4  Buzzards Bay > Westport > Adamsville Brook       NaN      NaN

# %%
#df['SUBW_NAME'].replace(r'^\s*$', np.nan, regex=True)
df = df_in.drop('Notes_AW',axis=1).dropna() # make a working copy
df['SUBW_NAME'].str.strip(to_strip = None) # remove whitespace
df.reset_index(inplace=True)
df.info()
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       68 non-null     int64
#  1   FID         68 non-null     int64
#  2   Lat         68 non-null     float64
#  3   Lon         68 non-null     float64
#  4   Region      68 non-null     object
#  5   MEP         68 non-null     object
#  6   Site_Name   68 non-null     object
#  7   Region_MEP  68 non-null     object
#  8   SUBW_NAME   68 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.9+ KB
#    index  FID        Lat        Lon    Region         MEP        Site_Name  \
# 0     20   21  41.714883 -70.384253  Cape Cod  Barnstable      Alder Brook
# 1     21   22  41.726801 -70.602171  Cape Cod    Phinneys       Back River
# 2     22   23  41.578791 -70.563246  Cape Cod         GBB     Backus Brook
# 3     23   24  41.711745 -70.379438  Cape Cod  Barnstable  Boat Cove Creek
# 4     24   25  41.576468 -70.551280  Cape Cod         GBB    Bournes Brook
#
#                                 Region_MEP  \
# 0      Cape Cod > Barnstable > Alder Brook
# 1         Cape Cod > Phinneys > Back River
# 2            Cape Cod > GBB > Backus Brook
# 3  Cape Cod > Barnstable > Boat Cove Creek
# 4           Cape Cod > GBB > Bournes Brook
#
#                                        SUBW_NAME
# 0                                     AlderCreek
# 1                           InnerBackRiverStream
# 2  MillPondFalmouth;BackusBrook;AshumetPond(11%)
# 3               BoatCoveCreek;MillPondBarnstable
# 4                   BournesBrook;AshumetPond(4%)

# %%
df.SUBW_NAME
# Out:
# 0                                        AlderCreek
# 1                              InnerBackRiverStream
# 2     MillPondFalmouth;BackusBrook;AshumetPond(11%)
# 3                  BoatCoveCreek;MillPondBarnstable
# 4                      BournesBrook;AshumetPond(4%)
#                           ...
# 63                                 UpperTashmooPond
# 64                                     MillBrookWTI
# 65                                  PeasePointBrook
# 66                                    TiasquamRiver
# 67                                       BlackBrook
# Name: SUBW_NAME, Length: 68, dtype: object

# %%
SUBW_NAME = [] # name of subwatershed in MEP data
PROPORTION = [] # proportion of flow draining to monitoring site at corresponding FID
FID = [] # FID of monitoring site
for i in range(len(df.FID)):
    print(i)
    #print(i,"|",df.Region_MEP[i])
    S = df.SUBW_NAME[i].split(";") # split column SUBW_NAME on semicolen
    #print(S)
    for s in S:
        match = fn_regex_search_0(s,"\(.*\)") # find parentheses
        replaced = fn_regex_search_replace(s,"\(.*\)","") # replace parentheses with blank

        digit = fn_regex_search_0(s,"\d+") # extract numeric digits
        if digit is 'NA':
            p = 1
        else:
            p = int(digit)/100 # calculate proportion of flow from digits
        print("  ",s,"|",replaced,"|",p)
        
        if fn_regex_search_0(replaced,"\w+") is 'NA':
            print("      empty... skipping to next")
            next # skip columns that dont have match
        
        # append values to lists
        SUBW_NAME.append(replaced)
        PROPORTION.append(p)
        FID.append(df.FID[i])
# Out:
# 0
#    AlderCreek | AlderCreek | 1
# 1
#    InnerBackRiverStream | InnerBackRiverStream | 1
# 2
#    MillPondFalmouth | MillPondFalmouth | 1
#    BackusBrook | BackusBrook | 1
#    AshumetPond(11%) | AshumetPond | 0.11
# 3
#    BoatCoveCreek | BoatCoveCreek | 1
#    MillPondBarnstable | MillPondBarnstable | 1
# 4
#    BournesBrook | BournesBrook | 1
#    AshumetPond(4%) | AshumetPond | 0.04
# 5
#    BridgeCreek | BridgeCreek | 1
# 6
#    FilendsPond | FilendsPond | 1
# 7
#    GaugeBayRd | GaugeBayRd | 1
#    CedarLakeFalmouth(54%) | CedarLakeFalmouth | 0.54
#    EdmundsPond(50%) | EdmundsPond | 0.5
# 8
#    RockHarborStream | RockHarborStream | 1
#    CedarPond | CedarPond | 1
# 9
#    BogWetlandYarmouth | BogWetlandYarmouth | 1
#    JabezNedsPond | JabezNedsPond | 1
#    HorsePond | HorsePond | 1
#    WellHorsePond | WellHorsePond | 1
# 10
#    ChaseGardenCreekFresh | ChaseGardenCreekFresh | 1
# 11
#    ChildsRiver | ChildsRiver | 1
#    JohnsPond(13%) | JohnsPond | 0.13
#    AshumetPond(4%) | AshumetPond | 0.04
#    GrassyPondFalmouth(46%) | GrassyPondFalmouth | 0.46
# 12
#    ColdSpringBrook | ColdSpringBrook | 1
#    BanksStBogs | BanksStBogs | 1
#    GrassPond | GrassPond | 1
#    PaddocksPond | PaddocksPond | 1
# 13
#    LowerCoonamessettRiver | LowerCoonamessettRiver | 1
#    FlaxPondFalmouthGreatPond | FlaxPondFalmouthGreatPond | 1
#    SpectaclePondFalmouth | SpectaclePondFalmouth | 1
#    ShallowPond | ShallowPond | 1
#    CrookedPond | CrookedPond | 1
#    DeepPondFalmouth | DeepPondFalmouth | 1
#    CoonamessettPond | CoonamessettPond | 1
#    RoundPondN | RoundPondN | 1
#    RoundPondS | RoundPondS | 1
# 14
#    SqueteagueStream | SqueteagueStream | 1
# 15
#    SaquatucketHarbor | SaquatucketHarbor | 1
#    WellChathamRd | WellChathamRd | 1
# 16
#      |   | 1
#       empty... skipping to next
# 17
#    FlaxPondFlamouthRandsCanal | FlaxPondFlamouthRandsCanal | 1
#    GaugeRandBeachRd | GaugeRandBeachRd | 1
# 18
#    ForestRoadBrook | ForestRoadBrook | 1
#    LongPondYarmouthStream | LongPondYarmouthStream | 1
#    LongPondYarmouth(%?) | LongPondYarmouth | 1
# 19
#    UpperFreshBrook | UpperFreshBrook | 1
# 20
#    FreshPondDennis | FreshPondDennis | 1
#    GaugeFreshPond | GaugeFreshPond | 1
# 21
#    SimmonsPondBarnstable | SimmonsPondBarnstable | 1
#    StraightwayPond(%?) | StraightwayPond | 1
# 22
#    GaugeHamblinBrook | GaugeHamblinBrook | 1
# 23
#    GaugeHatchesCreek | GaugeHatchesCreek | 1
# 24
#    HighToss | HighToss | 1
#    HerringPond(%32) | HerringPond | 0.32
#    RyderPond | RyderPond | 1
#    LongPondWellfleet(%29) | LongPondWellfleet | 0.29
#    SnowPond(57%) | SnowPond | 0.57
# 25
#    InnerHarborCreek | InnerHarborCreek | 1
# 26
#    NamskaketStream | NamskaketStream | 1
#    CliffPond(15%) | CliffPond | 0.15
#    LittleCliffPond(16%) | LittleCliffPond | 0.16
# 27
#      |   | 1
#       empty... skipping to next
# 28
#    PilgrimLake | PilgrimLake | 1
#    KescayoGansettStream | KescayoGansettStream | 1
# 29
#    WellCraigville8 | WellCraigville8 | 0.08
#    LakeElizabethRedLilyPond | LakeElizabethRedLilyPond | 1
# 30
#    LittleRiverBarnstable | LittleRiverBarnstable | 1
#    LovellsPond(%?) | LovellsPond | 1
# 31
#    LongHillCreek | LongHillCreek | 1
# 32
#    LakeWequaquetShallowPond(38%) | LakeWequaquetShallowPond | 0.38
#    LongPondBarnstableCenterville(15%) | LongPondBarnstableCenterville | 0.15
#    PineStreetStream | PineStreetStream | 1
# 33
#    MaraspinCreek | MaraspinCreek | 1
# 34
#    LowerMarstonsMillsRiverN | LowerMarstonsMillsRiverN | 1
# 35
#    GaugeMaryChase | GaugeMaryChase | 1
# 36
#    MashpeeWakebyPond | MashpeeWakebyPond | 1
#    SnakePond(%34) | SnakePond | 0.34
#    PimlicoPond | PimlicoPond | 1
#    PetersPond | PetersPond | 1
#    UpperMashpeeRiver | UpperMashpeeRiver | 1
#    CentralMashpeeRiver | CentralMashpeeRiver | 1
# 37
#    MillPondYarmouthLewisBay | MillPondYarmouthLewisBay | 1
# 38
#    MosquitoCreek | MosquitoCreek | 1
# 39
#    PahWahPondBog | PahWahPondBog | 1
# 40
#    PlashesBrook | PlashesBrook | 1
#    PlashesPond | PlashesPond | 1
# 41
#    UpperQuashnetRiver | UpperQuashnetRiver | 1
#    MoodyPond(44%) | MoodyPond | 0.44
#    SnakePond(28%) | SnakePond | 0.28
#    JohnsPond(87%) | JohnsPond | 0.87
#    WellTurnerRoad5 | WellTurnerRoad5 | 0.05
#    WellMashpee1 | WellMashpee1 | 0.01
# 42
#    StillwaterPond | StillwaterPond | 1
#    SchoolhousePond(69%) | SchoolhousePond | 0.69
#    LoversLake | LoversLake | 1
# 43
#    StillwaterPond | StillwaterPond | 1
#    SchoolhousePond(69%) | SchoolhousePond | 0.69
#    LoversLake | LoversLake | 1
# 44
#    SantuitPond | SantuitPond | 1
#    SantuitRiver | SantuitRiver | 1
# 45
#    GaugeJonesLn | GaugeJonesLn | 1
# 46
#    ShawmeLake | ShawmeLake | 1
#    UpperShawmeLake | UpperShawmeLake | 1
#    WellUpperCapeCooperative | WellUpperCapeCooperative | 1
# 47
#    SkunknetRiver | SkunknetRiver | 1
#    SouthPond | SouthPond | 1
#    WestPond | WestPond | 1
#    NorthPond | NorthPond | 1
#    WellLumbertMills | WellLumbertMills | 1
# 48
#    SnowsCreek | SnowsCreek | 1
# 49
#    SpringHillCreek | SpringHillCreek | 1
#    WellBoilingSpring(24%) | WellBoilingSpring | 0.24
# 50
#    StewartsCreek | StewartsCreek | 1
# 51
#    LoversLake | LoversLake | 1
# 52
#    LoversLake | LoversLake | 1
# 53
#    LittlePondStream | LittlePondStream | 1
# 54
#    LittleNamskaketStream | LittleNamskaketStream | 1
# 55
#    TarKilnStream | TarKilnStream | 1
# 56
#      |   | 1
#       empty... skipping to next
# 57
#    AllenHarborStream | AllenHarborStream | 1
# 58
#    HydawayLaneStream | HydawayLaneStream | 1
# 59
#    MillPondYarmouthBassRiver | MillPondYarmouthBassRiver | 1
#    MillStream | MillStream | 1
#    GaugeHamblinBrook | GaugeHamblinBrook | 1
# 60
#    YarmouthWell#1 | YarmouthWell#1 | 0.01
#    WhitesBrookFresh | WhitesBrookFresh | 1
#    ElishasPond | ElishasPond | 1
# 61
#    DamPondFalmouth | DamPondFalmouth | 1
# 62
#    LowerCreek | LowerCreek | 1
# 63
#    UpperTashmooPond | UpperTashmooPond | 1
# 64
#    MillBrookWTI | MillBrookWTI | 1
# 65
#    PeasePointBrook | PeasePointBrook | 1
# 66
#    TiasquamRiver | TiasquamRiver | 1
# 67
#    BlackBrook | BlackBrook | 1

# %%
# create output dataframe
print(len(FID),
len(SUBW_NAME),
len(PROPORTION))
_ = pd.DataFrame({'FID':FID,
                       'SUBW_NAME':SUBW_NAME,
                       'PROPORTION':PROPORTION})
print(_)
print(df[['FID','Lat','Lon','Region_MEP']])
df_out = _.merge(df[['FID','Lat','Lon','Region_MEP']],on='FID')
print(df_out)
df_out.to_csv(os.path.join(odr,"df_monitoring_point_subs.csv"))
# Out:
# 136 136 136
#      FID             SUBW_NAME  PROPORTION
# 0     21            AlderCreek        1.00
# 1     22  InnerBackRiverStream        1.00
# 2     23      MillPondFalmouth        1.00
# 3     23           BackusBrook        1.00
# 4     23           AshumetPond        0.11
# ..   ...                   ...         ...
# 131   87      UpperTashmooPond        1.00
# 132   94          MillBrookWTI        1.00
# 133   96       PeasePointBrook        1.00
# 134   97         TiasquamRiver        1.00
# 135   98            BlackBrook        1.00
#
# [136 rows x 3 columns]
#     FID        Lat        Lon                               Region_MEP
# 0    21  41.714883 -70.384253      Cape Cod > Barnstable > Alder Brook
# 1    22  41.726801 -70.602171         Cape Cod > Phinneys > Back River
# 2    23  41.578791 -70.563246            Cape Cod > GBB > Backus Brook
# 3    24  41.711745 -70.379438  Cape Cod > Barnstable > Boat Cove Creek
# 4    25  41.576468 -70.551280           Cape Cod > GBB > Bournes Brook
# ..  ...        ...        ...                                      ...
# 63   87  41.448448 -70.622340          Islands > Tashmoo > Fish Ladder
# 64   94  41.382724 -70.671990          Islands > Tisbury  > Mill Brook
# 65   96  41.345669 -70.760293   Islands > Menemsha > Pease Point Brook
# 66   97  41.377733 -70.677676      Islands > Tisbury  > Tiasquam River
# 67   98  41.352459 -70.762214      Islands > Menemsha > Un-named Brook
#
# [68 rows x 4 columns]
#      FID             SUBW_NAME  PROPORTION        Lat        Lon  \
# 0     21            AlderCreek        1.00  41.714883 -70.384253
# 1     22  InnerBackRiverStream        1.00  41.726801 -70.602171
# 2     23      MillPondFalmouth        1.00  41.578791 -70.563246
# 3     23           BackusBrook        1.00  41.578791 -70.563246
# 4     23           AshumetPond        0.11  41.578791 -70.563246
# ..   ...                   ...         ...        ...        ...
# 131   87      UpperTashmooPond        1.00  41.448448 -70.622340
# 132   94          MillBrookWTI        1.00  41.382724 -70.671990
# 133   96       PeasePointBrook        1.00  41.345669 -70.760293
# 134   97         TiasquamRiver        1.00  41.377733 -70.677676
# 135   98            BlackBrook        1.00  41.352459 -70.762214
#
#                                  Region_MEP
# 0       Cape Cod > Barnstable > Alder Brook
# 1          Cape Cod > Phinneys > Back River
# 2             Cape Cod > GBB > Backus Brook
# 3             Cape Cod > GBB > Backus Brook
# 4             Cape Cod > GBB > Backus Brook
# ..                                      ...
# 131         Islands > Tashmoo > Fish Ladder
# 132         Islands > Tisbury  > Mill Brook
# 133  Islands > Menemsha > Pease Point Brook
# 134     Islands > Tisbury  > Tiasquam River
# 135     Islands > Menemsha > Un-named Brook
#
# [136 rows x 6 columns]
